# %% [markdown]
# <h1 align="center"> Input And Output</h1>

# %% [markdown]
# #### Python provides numerous built-in functions that are readily available to us at the Python prompt.
#
# #### Some of the functions like input() and print() are widely used for standard input and output operations respectively. Let us see the output section first.
# #### print() is for output and input() for taking input from the user.

# %% [markdown]
# ### Output Using print() function
#
# #### We use the print() function to output data to the standard output device (screen). We can also output data to a file, but this will be discussed later.

# %%
# simple print funtion is used to print the output in python
print("Hi we are from colearning lounge!")
# Out:
# Hi we are from colearning lounge!

# %% [markdown]
# ### Their are many ways to print a particular object in python
# ### Important Note in pyhton each and every thing is an ibject

# %%
#lets see how to output a particular varable in python
name = "colearning lounge"
print(name)
print

# printing a variable along with the string usinf %s for string %d for int etc
print("we are from %s"%name)
print

#printing using the .format this .format is very use and make our code more readable.
print('Hello {name}, {greeting}'.format(greeting = 'Goodmorning', name = 'John'))

x = 5; y = 10
print('The value of x is {} and y is {}'.format(x,y))
# Out:
# colearning lounge
#
# we are from colearning lounge
#
# Hello John, Goodmorning
# The value of x is 5 and y is 10

# %% [markdown]
# #### Not only the normal variable like string, int we can also print the list, tuple and dictonaries also using the print function

# %%
# Printing the list 
name_list = ['We', 'are', 'from', 'India']
print(name_list)

#simple print function output a newline
print

# we can print the each and every valu of the list by iteration
print("Iterating over list and printing")
print

for name in name_list:
    print(name)
# Out:
# ['We', 'are', 'from', 'India']
#
# Iterating over list and printing
#
# We
# are
# from
# India

# %% [markdown]
# <h1 align='center'> Python Output</h1>

# %% [markdown]
# #### Up until now, our programs were static. The value of variables was defined or hard coded into the source code.
#
# #### To allow flexibility, we might want to take the input from the user. In Python, we have the input() function to allow this. The syntax for input() is

# %%
# their are differnt way we can use the input function
#simply letrs see how to take input a string

name = raw_input()
print("My name is %s"%name)
# Out:
# My name is

# %%
# if we want take integrer as a input we can type cast the input
duration = int(input())
print("DUration of my short film is %d"%duration)
# Out:
# 1
# DUration of my short film is 1

# %%
#In most of the competetive programming we see that we need to take the space separated input so ets see

numbers =  map(int, raw_input().split())
print numbers
# Out:
# 1
# [1]

# %% [markdown]
# <h1 align='middle'> File Handling </h1>

# %% [markdown]
# #### Lets see what file handiling is
#
# #### File handling in any prigramming language is manipulating the file using that particu;ar language.
#
# #### For Example
# #### Opening a file and reading the data in that file, Opening and writing data into that file.
#
# #### Python has a built−in function, open, for opening a file on disk. open returns a file object, which has methods and attributes for getting information about and manipulating the opened file.
#
# #### We can open a particular file in different modes like read, write, apppend.
# #### Wirte fucntion cleans all the data present init when ever we open a file usin worte mode.
# #### append mode will insert the data at the end of the prevous data present in that file.
# #### One thing to remember bydefault open funtion open any file in read mode.
# #### To open any file in read mode the file should be present if not it will throw an error.
# #### If we open the file in 'w' (write) mode if file is not present it will automatically create the file in specofied path.
# #### As as we open file in append mode it will create the file iof file is not present in that dir.

# %%
# Lets us open a file and try to read the ciontent in that file
# One thing to remember bydefault open funtion open any file in read mode
fp = open('cll.txt')
print(fp)

# mode give us the info about the file which mode the file is opened as i is 'r'.
# which means it is open in reading mode.
print(fp.mode)
print(fp.name)
# Out:
# <open file 'cll.txt', mode 'r' at 0x7fde50313d20>
# r
# cll.txt

# %% [markdown]
# As we have seen above we have opened a file name cll.txt and one more thing while we are tryong to read any file is we need to give path for that file as of now the .py and .txt file is on the same dir we just gave the file name as an arugment. As we know the open() function return file pointer.

# %% [markdown]
# ### After you open a file, the first thing you'll want to do is read from it, as shown in the next example.
# #### A file object maintains state about the file it has open. The tell method of a file object tells you your current position in the open file. Since you haven't done anything with this file yet, the current position is 0, which is the beginning of the file.

# %%
# 
print(fp.tell())
# Out:
# 0

# %% [markdown]
# #### So now we have the file pointer using that file pointer let us try to read the content of the file
#
# #### Their are different tyoe od function to read the data of the file lest see all the types to read
#
# #### First read() function will read all the content of the file at one go.
# #### The advantage is we can have all the data of the file in our ram and easy to process/
# #### Disadvantage is WE HAVE ALL THE DATA OF THE FILE IN OUR RAM IF WE HAVE HUGE FILE TO READ AND WE DONT HAVE ENOUGH RAM TO STORE.

# %%
# Reading using the read() function
print(fp.read())
# Out:
# Just then another visitor entered the drawing room: Prince Andrew
# Bolkónski, the little princess’ husband. He was a very handsome young
# man, of medium height, with firm, clearcut features. Everything about
# him, from his weary, bored expression to his quiet, measured step,
# offered a most striking contrast to his quiet, little wife. It was
# evident that he not only knew everyone in the drawing room, but had
# found them to be so tiresome that it wearied him to look at or listen to
# them. And among all these faces that he found so tedious, none seemed
# to bore him so much as that of his pretty wife. He turned away from
# her with a grimace that distorted his handsome face, kissed Anna
# Pávlovna’s hand, and screwing up his eyes scanned the whole company.
#
# “You are off to the war, Prince?” said Anna Pávlovna.
#
# “General Kutúzov,” said Bolkónski, speaking French and stressing
# the last syllable of the general’s name like a Frenchman, “has been
# ...

# %%
# As we have read the file in the above cell the file pointer is at the end.
# So we have to get the pointer to the starting of the file using seek
fp.seek(0)
for line in fp.read():
    print(line)
# Out:
# J
# u
# s
# t
#
# t
# h
# e
# n
#
# a
# n
# o
# t
# h
# e
# r
#
# v
# i
# s
# i
# t
# o
# r
#
# e
# n
# t
# e
# r
# e
# d
#
# t
# h
# e
#
# d
# r
# a
# w
# i
# n
# g
#
# r
# o
# o
# m
# :
#
# P
# r
# i
# n
# c
# e
#
# A
# n
# d
# r
# e
# w
#
#
# B
# o
# l
# k
# �
# �
# n
# s
# k
# i
# ,
#
# t
# h
# e
#
# l
# i
# t
# t
# l
# e
#
# p
# r
# i
# n
# c
# e
# s
# s
# �
# �
# �
#
# h
# u
# s
# b
# a
# n
# d
# .
#
# H
# e
#
# w
# a
# s
#
# a
#
# v
# e
# r
# y
#
# h
# a
# n
# d
# s
# o
# m
# e
#
# y
# o
# u
# n
# g
#
#
# m
# a
# n
# ,
#
# o
# f
#
# m
# e
# d
# i
# u
# m
#
# h
# e
# i
# g
# h
# t
# ,
#
# w
# i
# t
# h
#
# f
# i
# r
# m
# ,
#
# c
# l
# e
# a
# r
# c
# u
# t
#
# f
# e
# a
# t
# u
# r
# e
# s
# .
#
# E
# v
# e
# r
# y
# t
# h
# i
# n
# g
#
# a
# b
# o
# u
# t
#
#
# h
# i
# m
# ,
#
# f
# r
# o
# m
#
# h
# i
# s
#
# w
# e
# a
# r
# y
# ,
#
# b
# o
# r
# e
# d
#
# e
# x
# p
# r
# e
# s
# s
# i
# o
# n
#
# t
# o
#
# h
# i
# s
#
# q
# u
# i
# e
# t
# ,
#
# m
# e
# a
# s
# u
# r
# e
# ...

# %% [markdown]
# #### See above we have tried to read the file in a loop as we all know that fp.read() retrive all the data in the file as a string
# #### So now we are looping over a string that is the resone whu it printed the each charecter in the file.

# %%
fp.seek(0)
print(fp.readline())
# Out:
# Just then another visitor entered the drawing room: Prince Andrew

# %%
for line in fp.readlines():
    print(line)
# Out:
# Bolkónski, the little princess’ husband. He was a very handsome young
#
# man, of medium height, with firm, clearcut features. Everything about
#
# him, from his weary, bored expression to his quiet, measured step,
#
# offered a most striking contrast to his quiet, little wife. It was
#
# evident that he not only knew everyone in the drawing room, but had
#
# found them to be so tiresome that it wearied him to look at or listen to
#
# them. And among all these faces that he found so tedious, none seemed
#
# to bore him so much as that of his pretty wife. He turned away from
#
# her with a grimace that distorted his handsome face, kissed Anna
#
# Pávlovna’s hand, and screwing up his eyes scanned the whole company.
#
#
#
# “You are off to the war, Prince?” said Anna Pávlovna.
#
#
#
# “General Kutúzov,” said Bolkónski, speaking French and stressing
#
# the last syllable of the general’s name like a Frenchman, “has been
#
# pleased to take me as an aide-de-camp....”
#
#
#
# ...

# %% [markdown]
# #### I think by now you have figured out the main difference between the different function to open the file
#
# #### .read() function reads the data in on go.
# #### readline() function reads one line at one go.
# #### readlines() function reads the file according to line wise.

# %%
fp.seek(0)
for line in fp.readline:
    print(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-daa63dac1639> in <module>()
#       1
#       2 fp.seek(0)
# ----> 3 for line in fp.readline:
#       4     print(line)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %% [markdown]
# #### Deliberatly i have writeen the above code as every one can think like this insted of the readlines we can use the readline in loop so that is the result we cannot iterate the readline function

# %% [markdown]
# <h1 align='center'> Closing Files</h1>
#
# #### Open files consume system resources, and depending on the file mode, other programs may not be able to access them. It's important to close files as soon as you're finished with them.

# %%
print(fp)
# Out:
# <open file 'cll.txt', mode 'r' at 0x7fde50313d20>

# %%
# The closed attribute of a file object indicates whether the object has a file open or not. 
# In this case, the file is still open (closed is False).
print(fp.closed)
# Out:
# False

# %% [markdown]
# #### To close a file, call the close method of the file object. This frees the lock (if any) that you were holding on the file, flushes buffered writes (if any) that the system hadn't gotten around to actually writing yet, and releases the system resources.

# %%
fp.close()

# %%
fp.closed
# Out:
# True
