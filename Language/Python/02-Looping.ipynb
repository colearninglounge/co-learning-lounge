# %% [markdown]
# # Loop

# %% [markdown]
# ### A loop is a programming sructure that repeats a sequence of instructions untill a specific condition is met.

# %% [markdown]
# > **Types Of Loops -**
# There are two types of loop in python.
# - while loop
# - for loop

# %% [markdown]
# ## while loop

# %% [markdown]
# > **Defination :** while loops repeat as long as a certain boolean condition is met.

# %% [markdown]
# ### Syntax -

# %% [markdown]
# > `while <condition>:
#     <statement/s>`

# %% [markdown]
# ### Example -

# %%
# printing number from 1 to n
n = 5
count = 1
while count <= n:
    print(count) #printing number(i.e value of count)
    count += 1  #incrementing the value of count by 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## for loop

# %% [markdown]
# > **Defination :** for loop iterate over a given sequence.

# %% [markdown]
# ### Syntax -

# %% [markdown]
# > `for <current> in <iterable>:
#     <statement/s>`

# %% [markdown]
# ### Example -

# %%
#printing number from 0 to 4
for num in range(5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### Note : range() function returns a new list with numbers of that specified range(stating from 0 by default).

# %%
#looping throug a string
for char in "string":
    print(char)
# Out:
# s
# t
# r
# i
# n
# g

# %% [markdown]
# ## else conditional statement with loops

# %% [markdown]
# > The else block just after for/while is executed only when the loop is not terminated by a break statement.

# %% [markdown]
# ### Example

# %%
#printing odd numbers from 1 to 10
for num in range(1,11,2):
    print(num)
else:
    print("No Break!")
# Out:
# 1
# 3
# 5
# 7
# 9
# No Break!

# %%
#printing even numbers from 1 to 10
num = 2
while num < 10:
    print(num)
    num += 2
else:
    print("No Break!")
# Out:
# 2
# 4
# 6
# 8
# No Break!

# %% [markdown]
# ---

# %% [markdown]
# # Control Statements

# %% [markdown]
# ### controls statements are use to control the flow of loops.

# %% [markdown]
# >control statements are -
# - break
# - continue

# %% [markdown]
# ## break statement

# %% [markdown]
# >break statement is use to exit from the "while" or "for" loop.

# %% [markdown]
# ### Examples

# %%
n = 5
count = 1
while count <= n:
    print(count) #printing number(i.e value of count)
    count += 1  #incrementing the value of count by 1
    if count == 3:
        break #it will stop the loop
# Out:
# 1
# 2

# %%
for num in range(5):
    print(num)
    if num == 3:
        break
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## continue statement

# %% [markdown]
# > continue is used to skip the current block and return to the for/while statement.

# %% [markdown]
# ### Examples

# %% [markdown]
# `n = 5
# count = 1
# while count <= n:
#     if count == 3:
#         continue #it will skip the loop
#     print(count) #printing number(i.e value of count)
#     count += 1  #incrementing the value of count by 1
# '''output
# 1
# 2
# 4'''`

# %% [markdown]
# ---

# %% [markdown]
# `for num in range(5):
#     if num == 3:
#         continue
#     print(num)
# '''output
# 1
# 2
# 4'''`

# %% [markdown]
# ---

# %% [markdown]
# **This tutorial is intended to be a public resource. As such, if you see any glaring inaccuracies or if a critical topic is missing, please feel free to point it out or (preferably) submit a pull request to improve the tutorial. Also, we are always looking to improve the scope of this article. For anything feel free to mail us @ colearninglounge@gmail.com**

# %% [markdown]
# ### The author of this article is Surya Prakash Giri.
# You can follow him on [Github](https://github.com/Akashgiri963), [Linkedin](https://www.linkedin.com/in/surya-prakash-giri-18024a195), [Instagram](https://instagram.com/suryaprakash_giri).
